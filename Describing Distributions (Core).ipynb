# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Load Data

# %%
df=pd.read_csv('medical_data.csv')
df.head()
# Out:
#    Unnamed: 0 State       Lat       Lng      Area  Children  Age    Income  \
# 0           1    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93
# 1           2    FL  30.84513 -85.22907     Urban       3.0   51  46805.99
# 2           3    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14
# 3           4    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49
# 4           5    VA  37.59894 -76.88958     Rural       1.0   22   1209.56
#
#     Marital  Gender  ...  Hyperlipidemia  BackPain  Anxiety  \
# 0  Divorced    Male  ...             0.0       1.0      1.0
# 1   Married  Female  ...             0.0       0.0      0.0
# 2   Widowed  Female  ...             0.0       0.0      0.0
# 3   Married    Male  ...             0.0       0.0      0.0
# 4   Widowed  Female  ...             1.0       0.0      0.0
#
#    Allergic_rhinitis  Reflux_esophagitis  Asthma     Services  Initial_days  \
# ...

# %% [markdown]
# ### The "VitD_levels" column

# %% [markdown]
# #### Plot a histogram with a kde

# %%
feature = df['VitD_levels']
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
sns.histplot(data=df, x=feature, ax=ax,stat='probability', kde = True, color='navy');
ax.legend()

# %% [markdown]
# #### Is it Discrete or Continuous?

# %% [markdown]
# It is continous because it takes infinite number of values.

# %% [markdown]
# #### Does it have a skew? If so, which direction (+/-)

# %% [markdown]
# We don't have a skew because it is a symmetrical distribution.

# %% [markdown]
# #### What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# the Kurtosis is equal to 3, so it is Mesokurtic.

# %% [markdown]
# ### The "Doc_visits" column

# %% [markdown]
# #### Plot a histogram with a kde

# %%
feature = df['Doc_visits']
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
sns.histplot(data=df, x=feature, ax=ax,stat='probability', kde = True, color='navy');
ax.legend()

# %% [markdown]
# #### Is it Discrete or Continuous?

# %% [markdown]
# It is discrete because It takes on certain values

# %% [markdown]
# #### Does it have a skew? If so, which direction (+/-)

# %% [markdown]
# We don't have a skew because it is a symmetrical distribution.

# %% [markdown]
# #### What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# the Kurtosis is less than 3, so it is Platykurtic.

# %% [markdown]
# ### The "TotalCharge" column

# %% [markdown]
# #### Plot a histogram with a kde

# %%
feature = df['TotalCharge']
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', label = f'Median = {median:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
sns.histplot(data=df, x=feature, ax=ax,stat='probability', kde = True, color='navy');
ax.legend()

# %% [markdown]
# #### Is it Discrete or Continuous?

# %% [markdown]
# It is continous because it takes infinite number of values.

# %% [markdown]
# #### Does it have a skew? If so, which direction (+/-)

# %% [markdown]
# It is positively skewed because most of the values are grouped to the left.

# %% [markdown]
# #### What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# the Kurtosis is more than 3, so it is Leptokurtic.
